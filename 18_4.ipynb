# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import albumentations as A  # dodajemy import albumentations

# Dodajemy własną implementację mish
def mish(x):
    return x * tf.math.tanh(tf.math.softplus(x))

tf.keras.utils.get_custom_objects().update({'mish': tf.keras.layers.Activation(mish)})

train, test = tf.keras.datasets.fashion_mnist.load_data()

# wydobycie obrazów oraz labelek
images, labels = train

# normalizacja wartości pikseli
images = (images/255.0).astype(np.float32)

# zapisujemy dane jako int
labels = labels.astype(np.int32)

X_train, X_test, y_train, y_test = \
    train_test_split(images, labels, test_size=0.1, random_state=10, stratify=labels)

# Przygotowanie transformacji za pomocą albumentations
transform = A.Compose([
    # A.Resize(32, 32),  # Slightly larger than target
    A.RandomCrop(28, 28, p=0.8),
    A.Rotate(limit=30, p=0.8),  # Small rotation
    A.HorizontalFlip(p=0.8),
    A.VerticalFlip(p=0.8),
    # A.CropAndPad(px=10, p=0.8),
    # A.Normalize(mean=[0.1307], std=[0.3081]),  # MNIST stats
    # A.ToTensorV2(),
])

def augment(image, label):
    # Konwertujemy obraz do formatu wymaganego przez albumentations
    image = tf.cast(image * 255, tf.uint8)
    
    # Definiujemy funkcję wykonującą augmentację na pojedynczym obrazie
    def apply_augmentation(img):
        img_np = img.numpy()
        augmented = transform(image=img_np)
        return augmented['image']
    
    # Używamy tf.py_function do wykonania operacji numpy w kontekście grafu TF
    augmented_image = tf.py_function(
        apply_augmentation,
        [image],
        tf.uint8
    )
    
    # Przywracamy kształt i normalizujemy
    augmented_image = tf.cast(augmented_image, tf.float32) / 255.0
    augmented_image.set_shape(image.shape)
    
    return augmented_image, label

# Przygotowanie datasetu
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.shuffle(1000)

# Tworzymy dwa datasety - oryginalny i augmentowany
original_ds = train_ds.batch(16)
augmented_ds = train_ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

# Łączymy oba datasety
ds = tf.data.Dataset.concatenate(original_ds, augmented_ds)
ds = ds.shuffle(1000)

def custom_lr_schedule(epoch, current_lr):
    decay_rate = 0.9
    decay_step = 2
    min_lr = 0.00005
    if epoch % decay_step == 0 and epoch != 0:
        return max(min_lr, current_lr * decay_rate**(epoch/decay_step))
    return max(min_lr, current_lr)

# Model z L2 regularyzacją
f_mnist_model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(1000, activation='mish'),
    Dense(300, activation='mish'),
    Dense(150, activation='relu'),
    Dense(50, activation='relu'),
    Dense(10, activation='softmax')
])

f_mnist_model.summary()

initial_lr = 0.0006
adam_optimizer = tf.keras.optimizers.Adam(
    learning_rate=initial_lr,
)

f_mnist_model.compile(
    optimizer=adam_optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
)

# Przygotowanie validation dataset
val_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(16)

train_stats = f_mnist_model.fit(
    ds,
    verbose=1,
    epochs=20,
    validation_data=val_ds,
    callbacks=[
        tf.keras.callbacks.ModelCheckpoint(
            filepath='best_model.h5',
            monitor='val_loss',
            save_best_only=True,
            save_weights_only=False,
            mode='min',
            verbose=1
        ),
        # tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.00005, verbose=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
        tf.keras.callbacks.LearningRateScheduler(custom_lr_schedule)
    ]
)

f_mnist_model.save('f_mnist_model_v2.h5')

# Wyświetlanie wyników
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(train_stats.history['accuracy'], label='Training Accuracy')
plt.plot(train_stats.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_stats.history['loss'], label='Training Loss')
plt.plot(train_stats.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# c:\Projekty\kodilla\modul_18\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1000)           │       785,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 300)            │       300,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 150)            │        45,150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 50)             │         7,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           510 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,138,510 (4.34 MB)
#  Trainable params: 1,138,510 (4.34 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 6746/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7778 - loss: 0.5985
# Epoch 1: val_loss improved from inf to 0.50426, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 78s 11ms/step - accuracy: 0.7778 - loss: 0.5984 - val_accuracy: 0.8122 - val_loss: 0.5043 - learning_rate: 6.0000e-04
# Epoch 2/20
# 6747/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8404 - loss: 0.4300
# Epoch 2: val_loss improved from 0.50426 to 0.39570, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 72s 11ms/step - accuracy: 0.8404 - loss: 0.4300 - val_accuracy: 0.8530 - val_loss: 0.3957 - learning_rate: 6.0000e-04
# Epoch 3/20
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8622 - loss: 0.3665
# Epoch 3: val_loss improved from 0.39570 to 0.37806, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 73s 11ms/step - accuracy: 0.8622 - loss: 0.3665 - val_accuracy: 0.8643 - val_loss: 0.3781 - learning_rate: 5.4000e-04
# Epoch 4/20
# 6748/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8725 - loss: 0.3413
# Epoch 4: val_loss improved from 0.37806 to 0.35886, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 83s 12ms/step - accuracy: 0.8725 - loss: 0.3413 - val_accuracy: 0.8640 - val_loss: 0.3589 - learning_rate: 5.4000e-04
# Epoch 5/20
# 6743/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8867 - loss: 0.3040
# Epoch 5: val_loss improved from 0.35886 to 0.35281, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 73s 11ms/step - accuracy: 0.8867 - loss: 0.3040 - val_accuracy: 0.8748 - val_loss: 0.3528 - learning_rate: 4.3740e-04
# Epoch 6/20
# 6747/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8932 - loss: 0.2875
# Epoch 6: val_loss improved from 0.35281 to 0.31838, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 83s 12ms/step - accuracy: 0.8931 - loss: 0.2876 - val_accuracy: 0.8818 - val_loss: 0.3184 - learning_rate: 4.3740e-04
# Epoch 7/20
# 6745/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9030 - loss: 0.2567
# Epoch 7: val_loss improved from 0.31838 to 0.29971, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 89s 13ms/step - accuracy: 0.9030 - loss: 0.2567 - val_accuracy: 0.8930 - val_loss: 0.2997 - learning_rate: 3.1886e-04
# Epoch 8/20
# 6745/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9077 - loss: 0.2421
# Epoch 8: val_loss did not improve from 0.29971
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 75s 11ms/step - accuracy: 0.9076 - loss: 0.2422 - val_accuracy: 0.8890 - val_loss: 0.3073 - learning_rate: 3.1886e-04
# Epoch 9/20
# 6745/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9167 - loss: 0.2197
# Epoch 9: val_loss did not improve from 0.29971
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 77s 11ms/step - accuracy: 0.9167 - loss: 0.2197 - val_accuracy: 0.8948 - val_loss: 0.3014 - learning_rate: 2.0921e-04
# Epoch 10/20
# 6748/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9227 - loss: 0.2051
# Epoch 10: val_loss did not improve from 0.29971
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 88s 13ms/step - accuracy: 0.9227 - loss: 0.2051 - val_accuracy: 0.8963 - val_loss: 0.3070 - learning_rate: 2.0921e-04
# Epoch 11/20
# 6746/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9291 - loss: 0.1859
# Epoch 11: val_loss improved from 0.29971 to 0.29722, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 91s 13ms/step - accuracy: 0.9291 - loss: 0.1859 - val_accuracy: 0.9005 - val_loss: 0.2972 - learning_rate: 1.2353e-04
# Epoch 12/20
# 6746/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9356 - loss: 0.1727
# Epoch 12: val_loss did not improve from 0.29722
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 77s 11ms/step - accuracy: 0.9356 - loss: 0.1728 - val_accuracy: 0.9003 - val_loss: 0.3004 - learning_rate: 1.2353e-04
# Epoch 13/20
# 6748/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9414 - loss: 0.1574
# Epoch 13: val_loss did not improve from 0.29722
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 75s 11ms/step - accuracy: 0.9414 - loss: 0.1575 - val_accuracy: 0.9025 - val_loss: 0.2985 - learning_rate: 6.5651e-05
# Epoch 14/20
# 6744/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9437 - loss: 0.1499
# Epoch 14: val_loss did not improve from 0.29722
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 70s 10ms/step - accuracy: 0.9437 - loss: 0.1499 - val_accuracy: 0.9045 - val_loss: 0.3036 - learning_rate: 6.5651e-05
# Epoch 15/20
# 6748/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9466 - loss: 0.1436
# Epoch 15: val_loss did not improve from 0.29722
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 73s 11ms/step - accuracy: 0.9466 - loss: 0.1436 - val_accuracy: 0.9035 - val_loss: 0.3031 - learning_rate: 5.0000e-05
# Epoch 16/20
# 6747/6750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9491 - loss: 0.1374
# Epoch 16: val_loss did not improve from 0.29722
# 6750/6750 ━━━━━━━━━━━━━━━━━━━━ 72s 11ms/step - accuracy: 0.9491 - loss: 0.1374 - val_accuracy: 0.9040 - val_loss: 0.3043 - learning_rate: 5.0000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
